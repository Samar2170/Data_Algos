# %%
import pandas as pd
import os

# %%
df = pd.read_csv('../nifty500_enp.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                               Company Name  \
# 0           0                              3M India Ltd.
# 1           1                             ABB India Ltd.
# 2           2  ABB Power Products and Systems India Ltd.
# 3           3                                   ACC Ltd.
# 4           4                       AIA Engineering Ltd.
#
#                    Industry      Symbol      eps        bv  insider_h  \
# 0            CONSUMER GOODS     3MINDIA  144.140  1695.911     76.480
# 1  INDUSTRIAL MANUFACTURING         ABB   13.960   170.186     75.000
# 2  INDUSTRIAL MANUFACTURING  POWERINDIA   25.976   220.029     77.024
# 3  CEMENT & CEMENT PRODUCTS         ACC   88.701   676.251     57.144
# 4  INDUSTRIAL MANUFACTURING      AIAENG   60.020   449.929     58.557
#
#       inst_h  float_pc         price    dv_avg       trn_avg
# 0   8.921000  0.229404  26391.400391 -0.001125  2.321755e+07
# 1  14.151000  0.247490   1495.650024 -0.000750  1.216263e+08
# ...

# %%
df['PE'] = df['price'] / df['eps']
df['PB'] = df['price']/df['bv']
