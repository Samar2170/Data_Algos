# %%
import fred

# %%
fred.key('103fe6a05fac1e7a52e99ebdba5257e6')

# %%
fred.categories(24)
# Out:
# {'categories': [{'id': 24, 'name': 'Monetary Data', 'parent_id': 32991}]}

# %%
fred.children(24)
# Out:
# {'categories': [{'id': 124, 'name': 'Monetary Base', 'parent_id': 24},
#   {'id': 123, 'name': 'Reserves', 'parent_id': 24},
#   {'id': 25, 'name': 'M1 and Components', 'parent_id': 24},
#   {'id': 29, 'name': 'M2 and Components', 'parent_id': 24},
#   {'id': 96, 'name': 'M2 Minus Small Time Deposits', 'parent_id': 24},
#   {'id': 28, 'name': 'M3 and Components', 'parent_id': 24},
#   {'id': 30, 'name': 'MZM', 'parent_id': 24},
#   {'id': 26, 'name': 'Memorandum Items', 'parent_id': 24},
#   {'id': 32242,
#    'name': 'Money Velocity',
#    'parent_id': 24,
#    'notes': 'Velocity is a ratio of nominal GDP to a measure of the money supply (M1 or M2).  It can be thought of as the rate of turnover in the money supply--that is, the number of times one dollar is used to purchase final goods and services included in GDP.'},
#   {'id': 122, 'name': 'Borrowings', 'parent_id': 24},
#   {'id': 32215, 'name': 'Factors Affecting Reserve Balances', 'parent_id': 24},
#   {'id': 32218,
# ...

# %%
fred.series('DCOILWTICO')
# Out:
# {'realtime_start': '2021-01-18',
#  'realtime_end': '2021-01-18',
#  'seriess': [{'id': 'DCOILWTICO',
#    'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'title': 'Crude Oil Prices: West Texas Intermediate (WTI) - Cushing, Oklahoma',
#    'observation_start': '1986-01-02',
#    'observation_end': '2021-01-11',
#    'frequency': 'Daily',
#    'frequency_short': 'D',
#    'units': 'Dollars per Barrel',
#    'units_short': '$ per Barrel',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2021-01-13 12:21:08-06',
#    'popularity': 80,
#    'notes': 'Definitions, Sources and Explanatory Notes (http://www.eia.doe.gov/dnav/pet/TblDefs/pet_pri_spt_tbldef2.asp)'}]}

# %%
df = fred.observations('DCOILWTICO')

# %%
import pandas as pd
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#   realtime_start realtime_end observation_start observation_end units  \
# 0     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 1     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 2     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 3     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 4     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
#
#    output_type file_type          order_by sort_order  count  offset   limit  \
# 0            1      json  observation_date        asc   9138       0  100000
# 1            1      json  observation_date        asc   9138       0  100000
# 2            1      json  observation_date        asc   9138       0  100000
# 3            1      json  observation_date        asc   9138       0  100000
# 4            1      json  observation_date        asc   9138       0  100000
#
#                                         observations
# ...

# %%
df.tail()
# Out:
#      realtime_start realtime_end observation_start observation_end units  \
# 9133     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 9134     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 9135     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 9136     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
# 9137     2021-01-18   2021-01-18        1600-01-01      9999-12-31   lin
#
#       output_type file_type          order_by sort_order  count  offset  \
# 9133            1      json  observation_date        asc   9138       0
# 9134            1      json  observation_date        asc   9138       0
# 9135            1      json  observation_date        asc   9138       0
# 9136            1      json  observation_date        asc   9138       0
# 9137            1      json  observation_date        asc   9138       0
#
#        limit                                       observations
# ...

# %%
import requests
res = requests.get('https://api.stlouisfed.org/fred/series/observations?series_id=DCOILWTICO&realtime_start=1776-07-04&realtime_end=9999-12-31&api_key=103fe6a05fac1e7a52e99ebdba5257e6&file_type=json')

# %%
df = res.json()

# %%
df = pd.DataFrame(df)

# %%
df.to_csv('SampleFRED.csv')

# %%
res = requests.get('https://api.stlouisfed.org/fred/series/observations?series_id=DCOILWTICO&observation_start=2016-02-04&observation_end=2020-12-31&api_key=103fe6a05fac1e7a52e99ebdba5257e6&file_type=json&frequency=w')

# %%
res.json()
# Out:
# {'realtime_start': '2021-01-18',
#  'realtime_end': '2021-01-18',
#  'observation_start': '2016-02-04',
#  'observation_end': '2020-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 257,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'date': '2016-02-05',
#    'value': '31.26'},
#   {'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'date': '2016-02-12',
#    'value': '28.14'},
#   {'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'date': '2016-02-19',
#    'value': '30.02'},
#   {'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'date': '2016-02-26',
#    'value': '31.32'},
#   {'realtime_start': '2021-01-18',
#    'realtime_end': '2021-01-18',
#    'date': '2016-03-04',
#    'value': '34.43'},
#   {'realtime_start': '2021-01-18',
# ...
