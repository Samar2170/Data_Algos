# %%
import os
import pandas as pd
os.getcwd()
# Out:
# '/home/samar/Desktop/PROJECTS/Homer_3/FinanceDB/Assets'

# %%
df = pd.read_csv('NSE/BS/TCS_stnd_BS.csv')
df.head()
# Out:
#    Unnamed: 0                                                  0        1  \
# 0           0  Balance Sheet of Tata Consultancy Services (in...   Mar 21
# 1           1                                                NaN  12 mths
# 2           2                           EQUITIES AND LIABILITIES      NaN
# 3           3                                SHAREHOLDER'S FUNDS      NaN
# 4           4                               Equity Share Capital    370.0
#
#          2        3        4        5   6
# 0   Mar 20   Mar 19   Mar 18   Mar 17 NaN
# 1  12 mths  12 mths  12 mths  12 mths NaN
# 2      NaN      NaN      NaN      NaN NaN
# 3      NaN      NaN      NaN      NaN NaN
# 4    375.0    375.0    191.0    197.0 NaN

# %%
df.drop(['Unnamed: 0','6'],axis=1, inplace=True)
df.head()
# Out:
#                                                    0        1        2  \
# 0  Balance Sheet of Tata Consultancy Services (in...   Mar 21   Mar 20
# 1                                                NaN  12 mths  12 mths
# 2                           EQUITIES AND LIABILITIES      NaN      NaN
# 3                                SHAREHOLDER'S FUNDS      NaN      NaN
# 4                               Equity Share Capital    370.0    375.0
#
#          3        4        5
# 0   Mar 19   Mar 18   Mar 17
# 1  12 mths  12 mths  12 mths
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4    375.0    191.0    197.0

# %%
df = df.set_index('0')
df.head()
# Out:
#                                                           1        2        3  \
# 0
# Balance Sheet of Tata Consultancy Services (in ...   Mar 21   Mar 20   Mar 19
# NaN                                                 12 mths  12 mths  12 mths
# EQUITIES AND LIABILITIES                                NaN      NaN      NaN
# SHAREHOLDER'S FUNDS                                     NaN      NaN      NaN
# Equity Share Capital                                  370.0    375.0    375.0
#
#                                                           4        5
# 0
# Balance Sheet of Tata Consultancy Services (in ...   Mar 18   Mar 17
# NaN                                                 12 mths  12 mths
# EQUITIES AND LIABILITIES                                NaN      NaN
# SHAREHOLDER'S FUNDS                                     NaN      NaN
# Equity Share Capital                                  191.0    197.0

# %%
df.columns = df.iloc[0]

df.isna().sum().sum()
# Out:
# 80

# %%
df.head()
# Out:
# Balance Sheet of Tata Consultancy Services (in Rs. Cr.)   Mar 21   Mar 20  \
# 0
# Balance Sheet of Tata Consultancy Services (in ...        Mar 21   Mar 20
# NaN                                                      12 mths  12 mths
# EQUITIES AND LIABILITIES                                     NaN      NaN
# SHAREHOLDER'S FUNDS                                          NaN      NaN
# Equity Share Capital                                       370.0    375.0
#
# Balance Sheet of Tata Consultancy Services (in Rs. Cr.)   Mar 19   Mar 18  \
# 0
# Balance Sheet of Tata Consultancy Services (in ...        Mar 19   Mar 18
# NaN                                                      12 mths  12 mths
# EQUITIES AND LIABILITIES                                     NaN      NaN
# SHAREHOLDER'S FUNDS                                          NaN      NaN
# Equity Share Capital                                       375.0    191.0
#
# Balance Sheet of Tata Consultancy Services (in Rs. Cr.)   Mar 17
# ...

# %%
df = df.transpose()

# %%
df.head()
# Out:
# 0                                                  Balance Sheet of Tata Consultancy Services (in Rs. Cr.)  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                                         Mar 21
# Mar 20                                                                                         Mar 20
# Mar 19                                                                                         Mar 19
# Mar 18                                                                                         Mar 18
# Mar 17                                                                                         Mar 17
#
# 0                                                       NaN  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                              12 mths
# Mar 20                                              12 mths
# Mar 19                                              12 mths
# ...

# %%
df.columns
# Out:
# Index(['Balance Sheet of Tata Consultancy Services (in Rs. Cr.)',
#                                                              nan,
#                                       'EQUITIES AND LIABILITIES',
#                                            'SHAREHOLDER'S FUNDS',
#                                           'Equity Share Capital',
#                                            'Total Share Capital',
#                                           'Reserves and Surplus',
#                                     'Total Reserves and Surplus',
#                                       'Total Shareholders Funds',
#                                        'NON-CURRENT LIABILITIES',
#                                           'Long Term Borrowings',
#                                 'Deferred Tax Liabilities [Net]',
#                                    'Other Long Term Liabilities',
#                                           'Long Term Provisions',
# ...

# %%
df.at['Mar 21','Trade Payables']
# Out:
# '7962.00'

# %%
dd = df.filter(regex='Balance Sheet')
dd.columns
#cc = df.columns(lambda col: col.startswith('Balance Sheet of'), axis=1)
# Out:
# Index(['Balance Sheet of Tata Consultancy Services (in Rs. Cr.)'], dtype='object', name='0')

# %%
cc = df.columns.map(lambda x: x)

# %%
df.columns = df.columns.fillna('to_drop')
df.drop('to_drop', axis = 1, inplace = True)
df.head()
# Out:
# 0                                                  Balance Sheet of Tata Consultancy Services (in Rs. Cr.)  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                                         Mar 21
# Mar 20                                                                                         Mar 20
# Mar 19                                                                                         Mar 19
# Mar 18                                                                                         Mar 18
# Mar 17                                                                                         Mar 17
#
# 0                                                  EQUITIES AND LIABILITIES  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                  NaN
# Mar 20                                                                  NaN
# ...

# %%
c = df.at['Mar 21','FOB Value Of Goods']
cc = df.columns.map(lambda x: x.startswith("Balance Sheet"))

# %%
type(c)
# Out:
# str

# %%
cd = df.filter(regex=("Balance Sheet*"), axis=1)

# %%
df.drop(cd,axis=1,inplace=True)

# %%
df
# Out:
# 0                                                  EQUITIES AND LIABILITIES  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                  NaN
# Mar 20                                                                  NaN
# Mar 19                                                                  NaN
# Mar 18                                                                  NaN
# Mar 17                                                                  NaN
#
# 0                                                  SHAREHOLDER'S FUNDS  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                             NaN
# Mar 20                                                             NaN
# Mar 19                                                             NaN
# Mar 18                                                             NaN
# ...

# %%
df = df.fillna(-9999, )

# %%
df.replace(to_replace='--', value=-9999, inplace=True)

for i,d in enumerate(df.columns):
    if i == 0:
        print('NO')
    else:
        pd.to_numeric(df[d], downcast="float")
# Out:
# NO

# %%
df.head()
# Out:
# 0                                                   EQUITIES AND LIABILITIES  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                 -9999
# Mar 20                                                                 -9999
# Mar 19                                                                 -9999
# Mar 18                                                                 -9999
# Mar 17                                                                 -9999
#
# 0                                                   SHAREHOLDER'S FUNDS  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                            -9999
# Mar 20                                                            -9999
# Mar 19                                                            -9999
# Mar 18                                                            -9999
# ...

# %%
df.replace(-9999,0, inplace=True)

# %%
df.head()
# Out:
# 0                                                   EQUITIES AND LIABILITIES  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                     0
# Mar 20                                                                     0
# Mar 19                                                                     0
# Mar 18                                                                     0
# Mar 17                                                                     0
#
# 0                                                   SHAREHOLDER'S FUNDS  \
# Balance Sheet of Tata Consultancy Services (in ...
# Mar 21                                                                0
# Mar 20                                                                0
# Mar 19                                                                0
# Mar 18                                                                0
# ...

# %%
df.columns
# Out:
# Index(['EQUITIES AND LIABILITIES', 'SHAREHOLDER'S FUNDS',
#        'Equity Share Capital', 'Total Share Capital', 'Reserves and Surplus',
#        'Total Reserves and Surplus', 'Total Shareholders Funds',
#        'NON-CURRENT LIABILITIES', 'Long Term Borrowings',
#        'Deferred Tax Liabilities [Net]', 'Other Long Term Liabilities',
#        'Long Term Provisions', 'Total Non-Current Liabilities',
#        'CURRENT LIABILITIES', 'Short Term Borrowings', 'Trade Payables',
#        'Other Current Liabilities', 'Short Term Provisions',
#        'Total Current Liabilities', 'Total Capital And Liabilities', 'ASSETS',
#        'NON-CURRENT ASSETS', 'Tangible Assets', 'Intangible Assets',
#        'Capital Work-In-Progress', 'Other Assets', 'Fixed Assets',
#        'Non-Current Investments', 'Deferred Tax Assets [Net]',
#        'Long Term Loans And Advances', 'Other Non-Current Assets',
#        'Total Non-Current Assets', 'CURRENT ASSETS', 'Current Investments',
# ...

# %%
for d in df.columns:
    df[d] = df[d].astype(float)

# %%
df['DE'] = (df['Long Term Borrowings'] +  df['Short Term Borrowings']  )  /df['Total Reserves and Surplus']

# %%
df['R/P'] = df['Trade Receivables'] / df['Trade Payables']

# %%
df['CR'] = df['Total Current Assets'] / df['Total Current Liabilities']

# %%
df['CCR'] = df['Cash And Cash Equivalents'] / df['Total Current Assets']

# %%
df['Eq_Assets'] = df['Total Shareholders Funds'] / df['Total Capital And Liabilities']

# %%
df['FA_Assets'] = df['Fixed Assets'] / df['Total Assets']

# %%
df['NC_Assets'] = df['Total Non-Current Assets'] / df['Total Assets'] 
df['C_Assets'] = df['Total Current Assets'] / df['Total Assets']
